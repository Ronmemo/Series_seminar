# %%
import numpy as np
import pandas as pd
from scipy import stats

from matplotlib import pylab as plt
import seaborn as sns
# %matplotlib inline
sns.set()

import statsmodels.api as sm

# %% [markdown]
# # ARモデル

# %%
#AR(1)　(a)例
phi_1 = 0.8
c = 2
sigma = 1
T = 100

#初期値の設定
if phi_1 < 1:
    mu = c/(1-phi_1)
else:
    mu=0

epsilons = np.random.normal(0, sigma, size=T)

ar_data = np.zeros(T)
ar_data[0] = mu + epsilons[0]

for t in range(1, T):
    ar_data[t] = c + phi_1*ar_data[t-1] + epsilons[t]

plt.figure(figsize=(12, 8))
plt.plot(ar_data)

# %%
#AR(1)コレログラム
fig = plt.figure(figsize=(12,8))
ax1 = fig.add_subplot(211)
fig = sm.graphics.tsa.plot_acf(ar_data, lags=40, ax=ax1)
ax2 = fig.add_subplot(212)
fig = sm.graphics.tsa.plot_pacf(ar_data, lags=40, ax=ax2)

# %% [markdown]
# Q1. phi_1の値を変えてみて，気づくことを挙げよ（正負，絶対値）
#
# Q2. コレログラムの特徴を挙げよ（MAモデルとの比較）

# %% [markdown]
# # MAモデル

# %%
#MA(1) (a)例
T = 100
theta_1 = 20
sigma = 1
mu = 0

epsilons = np.random.normal(0, sigma, size=T)

ma_data = np.zeros(T)
ma_data[0] = mu + epsilons[0]

for t in range(1, T):
    ma_data[t] = mu+epsilons[t]+theta_1*epsilons[t-1]

plt.figure(figsize=(12, 8))
plt.plot(ma_data)

# %%
#MA(1)コレログラム
fig = plt.figure(figsize=(12,8))
ax1 = fig.add_subplot(211)
fig = sm.graphics.tsa.plot_acf(ma_data, lags=40, ax=ax1)
ax2 = fig.add_subplot(212)
fig = sm.graphics.tsa.plot_pacf(ma_data, lags=40, ax=ax2)

# %% [markdown]
# Q1. theta_1の値を変えてみて，気づくことを挙げよ（正負，絶対値）
#
# Q2. コレログラムの特徴を挙げよ（ARモデルとの比較）

# %% [markdown]
# # ARMAモデル

# %% [markdown]
# Q1. ARモデル，MAモデルのコードを参考に，ARMAモデルを実装せよ（パラメータは自由）
#
# Q2. 実装されたモデルについて次数選択を行い，評価を確認せよ（以下コードを動かす）

# %%
#ARMA(1,1)
phi_1 = -0.8
theta_1 = 0.8
c = 50
sigma = 1
T = 100

mu = c/(1-phi_1)

epsilons = np.random.normal(0, sigma, size=T)

arma_data = np.zeros(T)
arma_data[0] = mu + epsilons[0]

for t in range(1, T):
    arma_data[t] = c + phi_1*arma_data[t-1] +theta_1*epsilons[t-1] + epsilons[t]

plt.figure(figsize=(12, 8))
plt.plot(arma_data)

# %%
#次数決定（ARMA(1,1)の確認）
print(sm.tsa.arma_order_select_ic(arma_data, max_ar=3, max_ma=3, ic='aic'))
# Out:
# /Users/ryosukeokubo/.pyenv/versions/3.6.6/envs/tensorflow/lib/python3.6/site-packages/statsmodels/tsa/kalmanf/kalmanfilter.py:649: RuntimeWarning: divide by zero encountered in true_divide
#   R_mat, T_mat)
# /Users/ryosukeokubo/.pyenv/versions/3.6.6/envs/tensorflow/lib/python3.6/site-packages/statsmodels/tsa/tsatools.py:650: RuntimeWarning: overflow encountered in exp
#   newparams = ((1-np.exp(-params))/(1+np.exp(-params))).copy()
# /Users/ryosukeokubo/.pyenv/versions/3.6.6/envs/tensorflow/lib/python3.6/site-packages/statsmodels/tsa/tsatools.py:650: RuntimeWarning: invalid value encountered in true_divide
#   newparams = ((1-np.exp(-params))/(1+np.exp(-params))).copy()
# /Users/ryosukeokubo/.pyenv/versions/3.6.6/envs/tensorflow/lib/python3.6/site-packages/statsmodels/tsa/tsatools.py:651: RuntimeWarning: overflow encountered in exp
#   tmp = ((1-np.exp(-params))/(1+np.exp(-params))).copy()
# /Users/ryosukeokubo/.pyenv/versions/3.6.6/envs/tensorflow/lib/python3.6/site-packages/statsmodels/tsa/tsatools.py:651: RuntimeWarning: invalid value encountered in true_divide
#   tmp = ((1-np.exp(-params))/(1+np.exp(-params))).copy()
# /Users/ryosukeokubo/.pyenv/versions/3.6.6/envs/tensorflow/lib/python3.6/site-packages/statsmodels/base/model.py:488: HessianInversionWarning: Inverting hessian failed, no bse or cov_params available
#   'available', HessianInversionWarning)
# {'aic':             0           1           2           3
# 0  281.975950  282.409250  284.296623  285.736516
# 1  282.309952  284.141451  285.375598  288.394180
# 2  284.214009  282.982728  284.484260  287.041471
# 3  285.974132  283.421443  284.160665  283.749822, 'aic_min_order': (0, 0)}

# %% [markdown]
# # ARIMAモデル

# %% [markdown]
# Q1. ARMAモデルからARIMAモデルを生成するコードを書け（差分変換）

# %%
#ARIMA(1,1,1)
arima_data = np.diff(arma_data)

plt.figure(figsize=(12, 8))
plt.plot(arima_data)
